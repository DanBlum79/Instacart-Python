# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Nurse Blum\Instacart Basket Analysis'
path
# Out:
# 'C:\\Users\\Nurse Blum\\Instacart Basket Analysis'

# %%
# Import orders, products, and the new, order_products_prior dataframe
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_cleaned.csv'), index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_cleaned.csv'), index_col = False)

# %%
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             1           1   2398795        1             2
# 1             2           2    473747        1             3
# 2             3           3   2254736        1             4
# 3             4           4    431534        1             5
# 4             5           5   3367565        1             6
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   3                  7                    15.0
# 1                   3                 12                    21.0
# 2                   4                  7                    29.0
# 3                   4                 15                    28.0
# 4                   2                  7                    19.0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3214874, 8)

# %%
# 1. Merge dataframes
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.shape
# Out:
# (30356421, 12)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             1           1   2398795        1             2
# 1             1           1   2398795        1             2
# 2             1           1   2398795        1             2
# 3             1           1   2398795        1             2
# 4             1           1   2398795        1             2
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   3                  7                    15.0         196
# 1                   3                  7                    15.0       10258
# 2                   3                  7                    15.0       12427
# 3                   3                  7                    15.0       13176
# 4                   3                  7                    15.0       26088
#
#    add_to_cart_order  reordered _merge
# 0                  1          1   both
# 1                  2          0   both
# ...

# %%
# 2. Export merged file 
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
# 3. Import pickle file that you just exported
df_ords_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# 4. Check the shape
df_ords_combined.shape
# Out:
# (30356421, 12)

# %%
# 5. Merge new combined dataframe with df_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_ords_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             1           1   2398795        1             2
# 1             1           1   2398795        1             2
# 2             1           1   2398795        1             2
# 3             1           1   2398795        1             2
# 4             1           1   2398795        1             2
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   3                  7                    15.0         196
# 1                   3                  7                    15.0       10258
# 2                   3                  7                    15.0       12427
# 3                   3                  7                    15.0       13176
# 4                   3                  7                    15.0       26088
#
#    add_to_cart_order  reordered _merge
# 0                  1          1   both
# 1                  2          0   both
# ...

# %%
df_merged_xlarge = df_ords_combined.merge(df_prods, on = 'product_id', how = 'inner')

# %%
df_merged_xlarge.shape
# Out:
# (30328763, 17)

# %%
# 6. merge flag
df_merged_xlarge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             1             1   2398795        1             2
# 1             2             2    473747        1             3
# 2             3             3   2254736        1             4
# 3             4             4    431534        1             5
# 4             5             5   3367565        1             6
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   3                  7                    15.0         196
# 1                   3                 12                    21.0         196
# 2                   4                  7                    29.0         196
# 3                   4                 15                    28.0         196
# 4                   2                  7                    19.0         196
#
#    add_to_cart_order  reordered _merge  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
df_merged_xlarge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
